# %%
#Mount Google Drive.

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/My Drive/new/new'
# Out:
# /content/gdrive/My Drive/new/new

# %%
# !ls
# Out:
# 10.jpg	12.jpg	2.jpg  4.jpg  6.jpg  8.jpg  h_or_h.h5
# 11.jpg	1.jpg	3.jpg  5.jpg  7.jpg  9.jpg  video.mp4

# %%
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
model=tf.keras.models.load_model('h_or_h.h5')

# %%
import numpy as np
import cv2
from keras.preprocessing import image
# predicting images
path = '6.jpg'
imag = mpimg.imread(path)
img = image.load_img(path, target_size=(150, 150))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)

images = np.vstack([x])
classes = model.predict(images, batch_size=10)
print(classes)
plt.imshow(imag)
if classes[0]>0.8:
    print(" is a human")
else:
    print(" is a horse")
# Out:
# [[1.]]
#  is a human
